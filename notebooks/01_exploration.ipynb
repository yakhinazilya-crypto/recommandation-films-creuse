# %%
import pandas as pd
import glob
import os
import csv

def load_split_csv(file_prefix, folder='data'):
    
    search_pattern = os.path.join(folder, f"{file_prefix}*")
    files = sorted(glob.glob(search_pattern))
    
    if not files:
        print(search_pattern)
        return pd.DataFrame()
    
    
    df_list = []
    for f in files:
        try:
            # quoting=csv.QUOTE_NONE 
           
            df = pd.read_csv(
                f, 
                engine='python', 
                quoting=csv.QUOTE_NONE, 
                on_bad_lines='skip', 
                encoding='utf-8'
            )
            df_list.append(df)
        except Exception as e:
            print(f"Error reading {f}: {e}")
        

           
    
    if not df_list:
        return pd.DataFrame()
        
    return pd.concat(df_list, ignore_index=True)

df_movie = load_split_csv('movie_part_', folder='../data')
df_people = load_split_csv('people_temp_part_', folder='../data')
df_tmdb = load_split_csv('tmdb_full_part_', folder='.')

print(f"Movie rows: {len(df_movie)}")
print(f"People rows: {len(df_people)}")
print(f"TMDB rows: {len(df_tmdb)}")
# Out:
# Movie rows: 79088
# People rows: 2981595
# TMDB rows: 64715

# %%
os.listdir('../data')
# Out:
# ['df_final_creuse.csv',
#  'df_ml_ready.csv',
#  'movie.csv',
#  'movie_part_aa',
#  'movie_part_ab',
#  'names_temp.csv',
#  'people_temp.csv',
#  'people_temp_part_aa',
#  'people_temp_part_ab']

# %%
import gdown

url_data_base_complémentaire = "https://drive.google.com/uc?id=1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v"

gdown.download(
    url_data_base_complémentaire,
    "tmdb_full.csv",
    quiet=False
)

df_tmdb = pd.read_csv("tmdb_full.csv", low_memory=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v
# From (redirected): https://drive.google.com/uc?id=1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v&confirm=t&uuid=9dc2a6e1-5f0f-485d-a8e6-1f343e9fd693
# To: c:\Users\Zilya\Git\recommandation-films-creuse\notebooks\tmdb_full.csv
# 100%|██████████| 157M/157M [00:39<00:00, 3.97MB/s]

# %%
df_tmdb.shape
# Out:
# (309572, 25)

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309572 entries, 0 to 309571
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         309572 non-null  bool
#  1   backdrop_path                 151760 non-null  object
#  2   budget                        309572 non-null  int64
#  3   genres                        309572 non-null  object
#  4   homepage                      44262 non-null   object
#  5   id                            309572 non-null  int64
#  6   imdb_id                       309572 non-null  object
#  7   original_language             309572 non-null  object
#  8   original_title                309572 non-null  object
#  9   overview                      282512 non-null  object
#  10  popularity                    309572 non-null  float64
#  11  poster_path                   264159 non-null  object
#  12  production_countries          309572 non-null  object
#  13  release_date                  301339 non-null  object
#  14  revenue                       309572 non-null  int64
#  15  runtime                       309572 non-null  int64
#  16  spoken_languages              309572 non-null  object
#  17  status                        309572 non-null  object
#  18  tagline                       74573 non-null   object
#  19  title                         309572 non-null  object
#  20  video                         309572 non-null  bool
#  21  vote_average                  309572 non-null  float64
#  22  vote_count                    309572 non-null  int64
#  23  production_companies_name     309572 non-null  object
#  24  production_companies_country  164438 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(16)
# memory usage: 54.9+ MB

# %%
df_tmdb['genres'].head()
# Out:
# 0                        ['Comedy']
# 1                     ['Adventure']
# 2              ['Drama', 'Romance']
# 3      ['Drama', 'Comedy', 'Crime']
# 4    ['Drama', 'Comedy', 'Romance']
# Name: genres, dtype: object

# %%
df_tmdb = df_tmdb[df_tmdb['genres'].notna()] # Filtrer les lignes où 'genres' n'est pas NaN
df_tmdb['genres'].head()
# Out:
# 0                        ['Comedy']
# 1                     ['Adventure']
# 2              ['Drama', 'Romance']
# 3      ['Drama', 'Comedy', 'Crime']
# 4    ['Drama', 'Comedy', 'Romance']
# Name: genres, dtype: object

# %%
df_tmdb['overview'].isna().sum()
#df_tmdb = df_tmdb[df_tmdb['overview'].notna()]  # Filtrer les lignes où 'overview' n'est pas NaN
# Out:
# np.int64(27060)

# %%
df_tmdb['poster_path'].isna().sum()
# Out:
# np.int64(45413)

# %%
df_tmdb = df_tmdb[df_tmdb['poster_path'].notna()]
df_tmdb.shape
# Out:
# (264159, 25)

# %%
'vote_average' in df_tmdb.columns
df_tmdb = df_tmdb[df_tmdb['vote_average'] >= 5.0]
df_tmdb.shape
# Out:
# (156686, 25)

# %%
df_tmdb['year'] = pd.to_datetime(
    df_tmdb['release_date'],
    errors='coerce'
).dt.year
df_tmdb['year'].head()
# Out:
# 0    1938.0
# 2    1962.0
# 3    1988.0
# 4    1986.0
# 5    1995.0
# Name: year, dtype: float64

# %%
df_tmdb_year_pop = df_tmdb[['imdb_id', 'year', 'popularity']]

# %%
url_title_ratings = "https://datasets.imdbws.com/title.ratings.tsv.gz"


df_ratings = pd.read_csv(
    url_title_ratings,
    sep='\t',
    compression='gzip' 
)


df_final = df_movie.merge(
    df_ratings.rename(columns={'tconst': 'imdb_id', 'averageRating': 'rating'}), 
    on='imdb_id',
    how='left'
)


df_final.head()
# Out:
#                                              imdb_id  \
# 0                                        Larry Simms
# 1                                              7.708
# 2                                         Marc Meyer
# 3                                     "Robert August
# 4   icebound immensities of the South Pole as he ...
#
#                               title  \
# 0                             Daisy
# 1                                80
# 2                              None
# 3                    Michael Hynson
# 4   over a period of several months
#
#                                               genres         overview  \
# 0                                          Ann Doran    Dorothy Moore
# 1                   /x7Sz339F2oC8mBf0DHCQpKizXaL.jpg              NaN
# 2                                               None             None
# 3                                        Bruce Brown   Terence Bullen
# 4   they pursue a mutual sexual passion whose ine...            5.709
#
#             rating_x                           runtime      poster_path  \
# 0      Gene Lockhart                     Jonathan Hale    Gordon Oliver
# 1  "Ulrich Gehmacher                     Timo Novotny"             None
# 2               None                              None             None
# 3         Roy Crump"                    "Robert Bagley     Bruce Brown"
# 4                 69  /91O7z0vo7MiNWd5xD2BoivwbQsb.jpg  "Kieran O'Brien
#
#             actors     producers Chung  Chien-yu Fan  Ren-wei Liu"  \
# 0   Danny Mummert"           NaN   NaN           NaN           NaN
# 1             None          None   NaN           NaN           NaN
# 2             None          None   NaN           NaN           NaN
# 3             None          None   NaN           NaN           NaN
# 4   Margo Stilley"  Andrew Eaton   NaN           NaN           NaN
#
#   "Kang-shing Chen  Chin-sheng Yeh"  rating_y  numVotes
# 0              NaN              NaN       NaN       NaN
# 1              NaN              NaN       NaN       NaN
# 2              NaN              NaN       NaN       NaN
# 3              NaN              NaN       NaN       NaN
# 4              NaN              NaN       NaN       NaN

# %%
df_final = df_tmdb[
    [
        'title',
        'genres',
        'overview',
        'vote_average',
        'runtime',
        'poster_path',
        'imdb_id'
    ]
].copy()

df_final = df_final.rename(columns={
    'vote_average': 'rating'
})
df_final = df_final.merge(
    df_tmdb_year_pop,
    on='imdb_id',
    how='left'
)

df_final.head()
# Out:
#                  title                          genres  \
# 0              Blondie                      ['Comedy']
# 1       Love at Twenty            ['Drama', 'Romance']
# 2                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path    imdb_id    year  popularity
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg  tt0029927  1938.0       2.852
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg  tt0055747  1962.0       3.770
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg  tt0094675  1988.0       9.214
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg  tt0092149  1986.0       6.282
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg  tt0113101  1995.0      18.734

# %%
url_title_ratings = "https://datasets.imdbws.com/title.ratings.tsv.gz"
df_ratings = pd.read_csv(
    url_title_ratings,
    sep='\t'
)

df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2190
# 1  tt0000002            5.5       309
# 2  tt0000003            6.5      2290
# 3  tt0000004            5.1       196
# 4  tt0000005            6.2      3023

# %%
df_final = df_final.merge(
    df_ratings.rename(columns={'tconst': 'imdb_id'}),
    on='imdb_id',
    how='left'
)
df_final.head()
# Out:
#                  title                          genres  \
# 0              Blondie                      ['Comedy']
# 1       Love at Twenty            ['Drama', 'Romance']
# 2                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path    imdb_id    year  popularity  \
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg  tt0029927  1938.0       2.852
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg  tt0055747  1962.0       3.770
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg  tt0094675  1988.0       9.214
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg  tt0092149  1986.0       6.282
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg  tt0113101  1995.0      18.734
#
#    averageRating  numVotes
# 0            6.9     929.0
# 1            7.1    2559.0
# 2            7.4    9601.0
# 3            7.4    8445.0
# 4            6.7  116269.0

# %%
df_ratings = df_ratings[['tconst', 'numVotes']]
df_ratings.head()
# Out:
#       tconst  numVotes
# 0  tt0000001      2190
# 1  tt0000002       309
# 2  tt0000003      2290
# 3  tt0000004       196
# 4  tt0000005      3023

# %%
df_final.isna().sum()
# Out:
# title               0
# genres              0
# overview         7931
# rating              0
# runtime             0
# poster_path         0
# imdb_id             0
# year              310
# popularity          0
# averageRating    3744
# numVotes         3744
# dtype: int64

# %%
df_final = df_final.dropna(subset=['year', 'numVotes'])

# %%
df_final = df_final[df_final['year'] >= 1960]
df_final['overview'] = df_final['overview'].fillna('')
df_final['poster_path'] = df_final['poster_path'].fillna('')
df_final.head()
# Out:
#                  title                           genres  \
# 1       Love at Twenty             ['Drama', 'Romance']
# 2                Ariel     ['Drama', 'Comedy', 'Crime']
# 3  Shadows in Paradise   ['Drama', 'Comedy', 'Romance']
# 4           Four Rooms              ['Crime', 'Comedy']
# 5       Judgment Night  ['Action', 'Crime', 'Thriller']
#
#                                             overview  rating  runtime  \
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
# 5  While racing to a boxing match, Frank, Mike, J...   6.600      109
#
#                         poster_path    imdb_id    year  popularity  \
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg  tt0055747  1962.0       3.770
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg  tt0094675  1988.0       9.214
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg  tt0092149  1986.0       6.282
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg  tt0113101  1995.0      18.734
# 5  /3rvvpS9YPM5HB2f4HYiNiJVtdam.jpg  tt0107286  1993.0      10.797
#
#    averageRating  numVotes
# 1            7.1    2559.0
# 2            7.4    9601.0
# 3            7.4    8445.0
# 4            6.7  116269.0
# 5            6.6   20804.0

# %%
df_final.isna().sum()
# Out:
# title            0
# genres           0
# overview         0
# rating           0
# runtime          0
# poster_path      0
# imdb_id          0
# year             0
# popularity       0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
df_final.to_csv('../data/movie.csv', index=False)
df_tmdb = pd.read_csv("tmdb_full.csv", low_memory=False)

# %%
import pandas as pd

df_check = pd.read_csv('../data/movie.csv')
df_check.head()
# Out:
#                  title                           genres  \
# 0       Love at Twenty             ['Drama', 'Romance']
# 1                Ariel     ['Drama', 'Comedy', 'Crime']
# 2  Shadows in Paradise   ['Drama', 'Comedy', 'Romance']
# 3           Four Rooms              ['Crime', 'Comedy']
# 4       Judgment Night  ['Action', 'Crime', 'Thriller']
#
#                                             overview  rating  runtime  \
# 0  Love at Twenty unites five directors from five...   6.700      110
# 1  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 2  An episode in the life of Nikander, a garbage ...   7.182       76
# 3  It's Ted the Bellhop's first night on the job....   5.758       98
# 4  While racing to a boxing match, Frank, Mike, J...   6.600      109
#
#                         poster_path    imdb_id    year  popularity  \
# 0  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg  tt0055747  1962.0       3.770
# 1  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg  tt0094675  1988.0       9.214
# 2  /nj01hspawPof0mJmlgfjuLyJuRN.jpg  tt0092149  1986.0       6.282
# 3  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg  tt0113101  1995.0      18.734
# 4  /3rvvpS9YPM5HB2f4HYiNiJVtdam.jpg  tt0107286  1993.0      10.797
#
#    averageRating  numVotes
# 0            7.1    2559.0
# 1            7.4    9601.0
# 2            7.4    8445.0
# 3            6.7  116269.0
# 4            6.6   20804.0

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132948 entries, 0 to 132947
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   title          132948 non-null  object
#  1   genres         132948 non-null  object
#  2   overview       126751 non-null  object
#  3   rating         132948 non-null  float64
#  4   runtime        132948 non-null  int64
#  5   poster_path    132948 non-null  object
#  6   imdb_id        132948 non-null  object
#  7   year           132948 non-null  float64
#  8   popularity     132948 non-null  float64
#  9   averageRating  132948 non-null  float64
#  10  numVotes       132948 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 11.2+ MB

# %%
#Actors, producer, runtime are missing in the final dataset
import pandas as pd
# Load title.principals.tsv.gz in chunks
#En Python, le découpage de listes en morceaux (chunks) peut être réalisé via des fonctions personnalisées ou des outils comme itertools.zip_longest. 
# La fonction chunks permet de diviser une liste en sous-listes de taille fixe, utile pour traiter des données par groupes. 
# Cette technique est également appliquée dans des frameworks comme LangChain pour le traitement de texte, 
# où un grand document est segmenté en morceaux plus gérables pour l'analyse ou l'embedding.

url_principals = "https://datasets.imdbws.com/title.principals.tsv.gz"

chunks = pd.read_csv(
    url_principals,
    sep='\t',
    compression='gzip',
    chunksize=500_000
)
#df_principals = pd.concat(chunk[chunk['titleId'].isin(df_check['imdb_id'])] for chunk in chunks)
#tconst (ID film)
#nconst (ID people)

# %%
# Get the first chunk
first_chunk = next(chunks)
first_chunk.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
# Filter for actors, actresses, producers, directors
for chunk in chunks:
    people_chunk = chunk[
        chunk['category'].isin([
            'actor',
            'actress',
            'producer',
            'director'
        ])
    ]
    print(people_chunk['category'].value_counts())
    break
# Out:
# category
# actor       192880
# actress      89468
# director     30354
# producer     25012
# Name: count, dtype: int64

# %%
# Further filter to only include titles in our tmdb dataset
for chunk in chunks:
    people_chunk = chunk[
        chunk['category'].isin([
            'actor',
            'actress',
            'producer',
            'director'
        ])
    ]

    people_chunk = people_chunk[
        people_chunk['tconst'].isin(df_tmdb['imdb_id'])
    ]

    print(people_chunk.shape)
    break
# Out:
# (227456, 6)

# %%
# Reload chunks iterator
chunks = pd.read_csv(
    url_principals,
    sep='\t',
    compression='gzip',
    chunksize=500_000
)

# %%
# Write filtered people to CSV
people_file = '../data/people_temp.csv'

import os
# Remove file if it exists
if os.path.exists(people_file):
    os.remove(people_file)

first_write = True

for chunk in chunks:

    people_chunk = chunk[
        chunk['category'].isin([
            'actor',
            'actress',
            'producer',
            'director'
        ])
    ]

    people_chunk = people_chunk[
        people_chunk['tconst'].isin(df_tmdb['imdb_id'])
    ]

    if not people_chunk.empty:
        people_chunk.to_csv(
            people_file,
            mode='w' if first_write else 'a',
            index=False,
            header=first_write
        )
        first_write = False

# %%
# Load the filtered people data
df_people = pd.read_csv('../data/people_temp.csv')
df_people.shape
# Out:
# (3000691, 6)

# %%
import pandas as pd
# Load the filtered people data

df_people = pd.read_csv('../data/people_temp.csv', usecols=['nconst'])
needed_nconst = set(df_people['nconst'].unique())

len(needed_nconst)
# Out:
# 915715

# %%
url_names = "https://datasets.imdbws.com/name.basics.tsv.gz"
#Load name.basics.tsv.gz in chunks
names_chunks = pd.read_csv(
    url_names,
    sep='\t',
    compression='gzip',
    chunksize=500_000,
    usecols=['nconst', 'primaryName']
)

# %%
names_file = '../data/names_temp.csv'

import os
# Remove file if it exists
if os.path.exists(names_file):
    os.remove(names_file)

first_write = True

for chunk in names_chunks:

    names_chunk = chunk[
        chunk['nconst'].isin(needed_nconst)
    ]

    if not names_chunk.empty:
        names_chunk.to_csv(
            names_file,
            mode='w' if first_write else 'a',
            index=False,
            header=first_write
        )
        first_write = False

# %%
df_names = pd.read_csv('../data/names_temp.csv')
df_names.shape
# Out:
# (915693, 2)

# %%
# merge names with people: nconst, primaryName
df_people = pd.read_csv('../data/people_temp.csv')

df_people = df_people.merge(
    df_names,
    on='nconst',
    how='left'
)

# %%
df_people[['tconst', 'category', 'primaryName']].head()
# Out:
#       tconst  category           primaryName
# 0  tt0000001  director  William K.L. Dickson
# 1  tt0000001  producer  William K.L. Dickson
# 2  tt0000002  director         Émile Reynaud
# 3  tt0000003  director         Émile Reynaud
# 4  tt0000003  producer          Julien Pappé

# %%
df_people_small = df_people[['tconst', 'category', 'primaryName']]
df_people_small.head()
# Out:
#       tconst  category           primaryName
# 0  tt0000001  director  William K.L. Dickson
# 1  tt0000001  producer  William K.L. Dickson
# 2  tt0000002  director         Émile Reynaud
# 3  tt0000003  director         Émile Reynaud
# 4  tt0000003  producer          Julien Pappé

# %%
# Filter only actors and actresses
df_actors = df_people_small[
    (df_people_small['category'] == 'actor') |
    (df_people_small['category'] == 'actress')
]
df_actors.head()
# Out:
#        tconst category       primaryName
# 7   tt0000005    actor    Charles Kayser
# 8   tt0000005    actor          John Ott
# 10  tt0000007    actor  James J. Corbett
# 11  tt0000007    actor    Peter Courtney
# 16  tt0000008    actor          Fred Ott

# %%
# Group actors by tconst
df_actors_grouped = (
    df_actors
    .dropna(subset=['primaryName'])
    .groupby('tconst')['primaryName']
    .apply(lambda x: ', '.join(pd.unique(x.astype(str))))
    .reset_index()
    .rename(columns={'primaryName': 'actors'})
)

# %%
df_actors_grouped.head()
# Out:
#       tconst                            actors
# 0  tt0000005          Charles Kayser, John Ott
# 1  tt0000007  James J. Corbett, Peter Courtney
# 2  tt0000008                          Fred Ott
# 3  tt0000011                           Grunato
# 4  tt0000014      François Clerc, Benoît Duval

# %%
df_actors.shape
#df_people_small.head()
# Out:
# (2277780, 3)

# %%
#df_producers 
df_producers = df_people_small[
    (df_people_small['category'] == 'producer')]
df_producers.shape
# Out:
# (396159, 3)

# %%
df_producers['primaryName'].head()
# Merge producers with actors
# Out:
# 1     William K.L. Dickson
# 4             Julien Pappé
# 5            Émile Reynaud
# 9         Thomas A. Edison
# 14    William K.L. Dickson
# Name: primaryName, dtype: object

# %%
df_producers = df_producers.dropna(subset=['primaryName'])
df_producers_grouped = (
    df_producers
    .groupby('tconst')['primaryName']
    .apply(lambda x: ', '.join(pd.unique(x.astype(str))))
    .reset_index()
    .rename(columns={'primaryName': 'producers'})
)

# %%
df_producers_grouped.head()
# Out:
#       tconst                               producers
# 0  tt0000001                    William K.L. Dickson
# 1  tt0000003             Julien Pappé, Émile Reynaud
# 2  tt0000005                        Thomas A. Edison
# 3  tt0000007  William K.L. Dickson, Thomas A. Edison
# 4  tt0000008                    William K.L. Dickson

# %%
print(df_tmdb.columns.tolist())
# Out:
# ['adult', 'backdrop_path', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'production_companies_name', 'production_companies_country']

# %%
if 'release_date' in df_tmdb.columns:
   
    df_tmdb['year'] = pd.to_datetime(df_tmdb['release_date'], errors='coerce').dt.year

if 'vote_count' in df_tmdb.columns and 'numVotes' not in df_tmdb.columns:
     
    df_tmdb['numVotes'] = df_tmdb['vote_count']


cols_to_keep = [
    'imdb_id', 'title', 'genres', 'overview', 'vote_average', 
    'runtime', 'poster_path', 'numVotes', 'year', 'popularity'
]

df_final = df_tmdb[cols_to_keep].copy()

df_final = df_final.rename(columns={'vote_average': 'rating'})

# %%
df_final = df_tmdb[[
    'imdb_id',
    'title',
    'genres',
    'overview',
    'vote_average',
    'runtime',
    'poster_path',
    'popularity'
]].copy()

df_final = df_final.rename(columns={
    'vote_average': 'rating'
})

# %%
df_final.columns
df_final.shape
# Out:
# (309572, 8)

# %%
df_final['year'] = pd.to_datetime(
    df_tmdb['release_date'],
    errors='coerce'
).dt.year

# %%
df_final['year'].isna().sum()
# Out:
# np.int64(8233)

# %%
import pandas as pd

url_ratings = "https://datasets.imdbws.com/title.ratings.tsv.gz"

df_ratings = pd.read_csv(
    url_ratings,
    sep='\t',
    compression='gzip'
)

df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2190
# 1  tt0000002            5.5       309
# 2  tt0000003            6.5      2290
# 3  tt0000004            5.1       196
# 4  tt0000005            6.2      3023

# %%
df_final = df_final.merge(
    df_ratings[['tconst', 'numVotes']],
    left_on='imdb_id',
    right_on='tconst',
    how='left'
)

df_final = df_final.drop(columns='tconst')

# %%
df_final[['rating', 'numVotes']].head()
df_final['numVotes'].isna().sum()
# Out:
# np.int64(35765)

# %%
df_final = df_final[df_final['numVotes'] >= 50]
df_final.shape
# Out:
# (198165, 10)

# %%
df_final.head()
# Out:
#      imdb_id                title                          genres  \
# 0  tt0029927              Blondie                      ['Comedy']
# 2  tt0055747       Love at Twenty            ['Drama', 'Romance']
# 3  tt0094675                Ariel    ['Drama', 'Comedy', 'Crime']
# 4  tt0092149  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 5  tt0113101           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 2  Love at Twenty unites five directors from five...   6.700      110
# 3  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 4  An episode in the life of Nikander, a garbage ...   7.182       76
# 5  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path  popularity    year  numVotes
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg       2.852  1938.0     929.0
# 2  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg       3.770  1962.0    2559.0
# 3  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg       9.214  1988.0    9601.0
# 4  /nj01hspawPof0mJmlgfjuLyJuRN.jpg       6.282  1986.0    8445.0
# 5  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg      18.734  1995.0  116269.0

# %%
#final cleaning
df_final[['rating', 'overview']].isna().sum()
# Out:
# rating         0
# overview    7109
# dtype: int64

# %%
df_final['overview'] = df_final['overview'].fillna('')
df_final['rating'] = df_final['rating'].fillna(0.0)

# %%
df_final = df_final[df_final['rating'] >= 1.0]
df_final.shape
# Out:
# (177556, 10)

# %%
#reset index
df_final = df_final.reset_index(drop=True)
df_final.head()
# Out:
#      imdb_id                title                          genres  \
# 0  tt0029927              Blondie                      ['Comedy']
# 1  tt0055747       Love at Twenty            ['Drama', 'Romance']
# 2  tt0094675                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  tt0092149  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4  tt0113101           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path  popularity    year  numVotes
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg       2.852  1938.0     929.0
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg       3.770  1962.0    2559.0
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg       9.214  1988.0    9601.0
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg       6.282  1986.0    8445.0
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg      18.734  1995.0  116269.0

# %%
df_final[['rating', 'overview']].isna().sum()
# Out:
# rating      0
# overview    0
# dtype: int64

# %%
df_actors_grouped = (
    df_actors
    .groupby('tconst')['primaryName']
    .apply(lambda x: ', '.join(x.astype(str).unique()))
    .reset_index()
    .rename(columns={
        'tconst': 'imdb_id',
        'primaryName': 'actors'
    })
)
df_final = df_final.merge(
    df_actors_grouped,
    on='imdb_id',
    how='left'
)

# %%
df_final['actors'] = df_final['actors'].fillna('')
df_final.head()
# Out:
#      imdb_id                title                          genres  \
# 0  tt0029927              Blondie                      ['Comedy']
# 1  tt0055747       Love at Twenty            ['Drama', 'Romance']
# 2  tt0094675                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  tt0092149  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4  tt0113101           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path  popularity    year  numVotes  \
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg       2.852  1938.0     929.0
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg       3.770  1962.0    2559.0
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg       9.214  1988.0    9601.0
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg       6.282  1986.0    8445.0
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg      18.734  1995.0  116269.0
#
#                                               actors
# 0  Penny Singleton, Arthur Lake, Larry Simms, Dai...
# 1  Jean-Pierre Léaud, Marie-France Pisier, Eleono...
# 2  Turo Pajala, Susanna Haavisto, Matti Pellonpää...
# 3  Matti Pellonpää, Kati Outinen, Sakari Kuosmane...
# 4  Tim Roth, Antonio Banderas, Sammi Davis, Amand...

# %%
#add producers
df_final = df_final.merge(
    df_producers_grouped.rename(columns={'tconst': 'imdb_id'}),
    on='imdb_id',
    how='left'
)
df_final.head()
# Out:
#      imdb_id                title                          genres  \
# 0  tt0029927              Blondie                      ['Comedy']
# 1  tt0055747       Love at Twenty            ['Drama', 'Romance']
# 2  tt0094675                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  tt0092149  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4  tt0113101           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path  popularity    year  numVotes  \
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg       2.852  1938.0     929.0
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg       3.770  1962.0    2559.0
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg       9.214  1988.0    9601.0
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg       6.282  1986.0    8445.0
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg      18.734  1995.0  116269.0
#
#                                               actors        producers
# 0  Penny Singleton, Arthur Lake, Larry Simms, Dai...              NaN
# 1  Jean-Pierre Léaud, Marie-France Pisier, Eleono...  Pierre Roustang
# 2  Turo Pajala, Susanna Haavisto, Matti Pellonpää...   Aki Kaurismäki
# 3  Matti Pellonpää, Kati Outinen, Sakari Kuosmane...  Mika Kaurismäki
# 4  Tim Roth, Antonio Banderas, Sammi Davis, Amand...  Lawrence Bender

# %%
df_final['producers'] = df_final['producers'].fillna('')
df_final.isna().sum()
# Out:
# imdb_id           0
# title             0
# genres            0
# overview          0
# rating            0
# runtime           0
# poster_path    9443
# popularity        0
# year            136
# numVotes          0
# actors            0
# producers         0
# dtype: int64

# %%
df_final['poster_path'] = df_final['poster_path'].fillna('')
df_final['year'] = df_final['year'].fillna('')
df_final.isna().sum()
# Out:
# imdb_id        0
# title          0
# genres         0
# overview       0
# rating         0
# runtime        0
# poster_path    0
# popularity     0
# year           0
# numVotes       0
# actors         0
# producers      0
# dtype: int64

# %%
df_final.to_csv('../data/movie.csv', index=False)
df_final.head()
# Out:
#      imdb_id                title                          genres  \
# 0  tt0029927              Blondie                      ['Comedy']
# 1  tt0055747       Love at Twenty            ['Drama', 'Romance']
# 2  tt0094675                Ariel    ['Drama', 'Comedy', 'Crime']
# 3  tt0092149  Shadows in Paradise  ['Drama', 'Comedy', 'Romance']
# 4  tt0113101           Four Rooms             ['Crime', 'Comedy']
#
#                                             overview  rating  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...   7.214       70
# 1  Love at Twenty unites five directors from five...   6.700      110
# 2  Taisto Kasurinen is a Finnish coal miner whose...   7.046       73
# 3  An episode in the life of Nikander, a garbage ...   7.182       76
# 4  It's Ted the Bellhop's first night on the job....   5.758       98
#
#                         poster_path  popularity    year  numVotes  \
# 0   /zBiHKhXklvTFwj4M1uEUcQGAVJ.jpg       2.852  1938.0     929.0
# 1  /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg       3.770  1962.0    2559.0
# 2  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg       9.214  1988.0    9601.0
# 3  /nj01hspawPof0mJmlgfjuLyJuRN.jpg       6.282  1986.0    8445.0
# 4  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg      18.734  1995.0  116269.0
#
#                                               actors        producers
# 0  Penny Singleton, Arthur Lake, Larry Simms, Dai...
# 1  Jean-Pierre Léaud, Marie-France Pisier, Eleono...  Pierre Roustang
# 2  Turo Pajala, Susanna Haavisto, Matti Pellonpää...   Aki Kaurismäki
# 3  Matti Pellonpää, Kati Outinen, Sakari Kuosmane...  Mika Kaurismäki
# 4  Tim Roth, Antonio Banderas, Sammi Davis, Amand...  Lawrence Bender

# %%
df_check = pd.read_csv('../data/movie.csv')
df_check.isna().sum()
df_check.shape
# Out:
# (177556, 12)

# %%
df_final.to_csv("../data/df_ml_ready.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_final.to_csv("../data/df_ml_ready.csv", index=False)
#
# NameError: name 'df_final' is not defined
# KeyboardInterrupt

# %%
import requests
import time


TMDB_API_KEY = "secrets["TMDB_API_KEY"]"

def get_french_overview(imdb_id):
    """Функция для получения описания на французском через API"""
    try:
        # recherche TMDB ID et IMDb ID
        url_find = f"https://api.themoviedb.org/3/find/{imdb_id}?api_key={TMDB_API_KEY}&external_source=imdb_id"
        res = requests.get(url_find).json()
        
        movie_results = res.get('movie_results', [])
        if not movie_results:
            return None
        
        tmdb_id = movie_results[0]['id']
        
        
        url_detail = f"https://api.themoviedb.org/3/movie/{tmdb_id}?api_key={TMDB_API_KEY}&language=fr-FR"
        movie_data = requests.get(url_detail).json()
        
        return movie_data.get('overview')
    except:
        return None




#example popularity
df_to_translate = df_final.sort_values(by='popularity', ascending=False).head(1000)

for idx, row in df_to_translate.iterrows():
    fr_desc = get_french_overview(row['imdb_id'])
    if fr_desc and len(fr_desc) > 10: 
        df_final.at[idx, 'overview'] = fr_desc
    
    # api (40 demandes en 10 sec)
    time.sleep(0.1) 

print("traduction terminée!")
# Out:
# traduction terminée!

# %%
# filtration
df_ml_ready = df_final[
    (df_final['rating'] >= 6.0) & 
    (df_final['numVotes'] >= 1000)
].copy()

# les donnees pour STREAMLIT

# acteurs si nessasaire
if 'actors' not in df_ml_ready.columns and 'df_actors_grouped' in locals():
    df_ml_ready = df_ml_ready.merge(df_actors_grouped, on='imdb_id', how='left')

# les posters
def make_poster_url(path):
    if pd.isna(path) or path == "" or str(path) == "nan":
        return "https://via.placeholder.com/300x450?text=No+Poster"
    if str(path).startswith('http'):
        return path
    return f"https://image.tmdb.org/t/p/w500{path}"

df_ml_ready['poster_url'] = df_ml_ready['poster_path'].apply(make_poster_url)

# text pour ML (KNN)
df_ml_ready['genres_text'] = df_ml_ready['genres'].astype(str).str.replace(r"[\[\]']", "", regex=True)

# remplacer NAN
df_ml_ready['overview'] = df_ml_ready['overview'].fillna("Description bientôt disponible.")
df_ml_ready['actors'] = df_ml_ready['actors'].fillna("Casting non disponible")

# sevgarde
df_ml_ready.to_csv('../data/df_ml_ready.csv', index=False)
df_ml_ready.to_csv('../data/movie.csv', index=False)

print(f"✅ sevgarder {len(df_ml_ready)} films.")
print("posters, acteurs, genres prettes pour ML.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # filtration
# ----> 2 df_ml_ready = df_final[
#       3     (df_final['rating'] >= 6.0) &
#       4     (df_final['numVotes'] >= 1000)
#       5 ].copy()
#       7 # les donnees pour STREAMLIT
#       8
#       9 # acteurs si nessasaire
#      10 if 'actors' not in df_ml_ready.columns and 'df_actors_grouped' in locals():
#
# NameError: name 'df_final' is not defined

# %%
df_ml_ready.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_ml_ready.info()
#
# NameError: name 'df_ml_ready' is not defined

# %%
print(df_ml_ready[['title', 'imdb_id']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(df_ml_ready[['title', 'imdb_id']].head())
#
# NameError: name 'df_ml_ready' is not defined

# %%
# Проверим, есть ли хоть одно длинное описание (французские обычно длиннее "No description")
print(df_ml_ready['overview'].str.len().describe())

# Посмотрим на первые 5 строк, где должен быть перевод
print(df_ml_ready.sort_values(by='popularity', ascending=False)[['title', 'overview']].head())
# Out:
# count    32467.000000
# mean       288.857640
# std        172.239963
# min          0.000000
# 25%        157.000000
# 50%        244.000000
# 75%        382.000000
# max       1002.000000
# Name: overview, dtype: float64
#                                     title  \
# 23537                 The Pope's Exorcist
# 30260   Ant-Man and the Wasp: Quantumania
# 43941         The Super Mario Bros. Movie
# 100982           Avatar: The Way of Water
# 18663                             Ghosted
#
#                                                  overview
# 23537   Inspiré des véritables archives du Père Gabrie...
# 30260   Tout va pour le mieux : Scott a écrit un livre...
# 43941   Alors qu’ils tentent de réparer une canalisati...
# 100982  Une dizaine d'années s'est écoulée depuis les ...
# 18663   Cole, un agriculteur sans histoire, tombe éper...
